# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df = pd.read_csv("Hostel_City_Ratings.csv", index_col=[0])
df.head()
df_copy = df.copy()

df_copy
# Out:
#    Planet Traveler Hostel  Samesun Toronto  The Only Backpacker's Inn  \
# 0                     9.8              9.1                        9.0
# 1                     9.4              8.8                        8.6
# 2                     9.9              9.1                        9.0
# 3                     9.6              8.2                        8.3
# 4                     9.7              8.4                        8.3
# 5                     9.4              8.2                        8.5
# 6                     9.4              8.1                        8.2
#
#    All Days Hostel  King St West and Spadina Ave  The Clarence Park  \
# 0              9.0                           9.0                8.6
# 1              9.4                          10.0                9.0
# 2              8.9                           9.8                7.9
# 3              7.6                           9.0                7.7
# 4              8.9                           8.6                8.6
# 5              8.6                           8.6                8.0
# 6              8.5                           8.1                8.0
#
#    The Parkdale Hostellerie  YYZ Nomads Women's Only Hostel  49 Hostel  \
# 0                       7.5                             9.6        9.0
# 1                       7.6                             9.7        9.7
# 2                       7.9                             9.9        8.7
# 3                       6.1                             9.5        8.0
# 4                       5.7                             9.9        8.7
# 5                       6.7                             9.8        9.3
# 6                       5.8                             9.8        7.7
#
#    Palmerston Hotel  Zen Hostel  Ode Hostel  Great Stays Toronto 1  \
# 0                 6           2          10                      2
# 1                 9           2           8                      4
# 2                 7           2          10                      6
# 3                 7           2          10                      2
# 4                 7           2          10                      2
# 5                 7           2           8                      2
# 6                 7           2          10                      2
#
#    Comfy Guest House and Suite  Toronto Furnished Living  Pembroke Inn  \
# 0                          9.0                         2            10
# 1                          8.0                         2            10
# 2                          8.5                        10            10
# 3                          6.0                         2            10
# 4                          8.0                         2            10
# 5                          8.5                         2             8
# 6                          7.5                         2            10
#
#    St. Lawrence Residences & Suites
# 0                                 6
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 2
# 5                                 2
# 6                                 2

# %%
df_test = df_copy.set_axis(['Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value', 'Facilities'], axis=0, copy=True)

# %%
df_test.loc['Average']= df.mean()
df_test
# Out:
#              Planet Traveler Hostel  Samesun Toronto  \
# Security                        9.8         9.100000
# Location                        9.4         8.800000
# Staff                           9.9         9.100000
# Atmosphere                      9.6         8.200000
# Cleanliness                     9.7         8.400000
# Value                           9.4         8.200000
# Facilities                      9.4         8.100000
# Average                         9.6         8.557143
#
#              The Only Backpacker's Inn  All Days Hostel  \
# Security                      9.000000              9.0
# Location                      8.600000              9.4
# Staff                         9.000000              8.9
# Atmosphere                    8.300000              7.6
# Cleanliness                   8.300000              8.9
# Value                         8.500000              8.6
# Facilities                    8.200000              8.5
# Average                       8.557143              8.7
#
#              King St West and Spadina Ave  The Clarence Park  \
# Security                         9.000000           8.600000
# Location                        10.000000           9.000000
# Staff                            9.800000           7.900000
# Atmosphere                       9.000000           7.700000
# Cleanliness                      8.600000           8.600000
# Value                            8.600000           8.000000
# Facilities                       8.100000           8.000000
# Average                          9.014286           8.257143
#
#              The Parkdale Hostellerie  YYZ Nomads Women's Only Hostel  \
# Security                     7.500000                        9.600000
# Location                     7.600000                        9.700000
# Staff                        7.900000                        9.900000
# Atmosphere                   6.100000                        9.500000
# Cleanliness                  5.700000                        9.900000
# Value                        6.700000                        9.800000
# Facilities                   5.800000                        9.800000
# Average                      6.757143                        9.742857
#
#              49 Hostel  Palmerston Hotel  Zen Hostel  Ode Hostel  \
# Security      9.000000          6.000000         2.0   10.000000
# Location      9.700000          9.000000         2.0    8.000000
# Staff         8.700000          7.000000         2.0   10.000000
# Atmosphere    8.000000          7.000000         2.0   10.000000
# Cleanliness   8.700000          7.000000         2.0   10.000000
# Value         9.300000          7.000000         2.0    8.000000
# Facilities    7.700000          7.000000         2.0   10.000000
# Average       8.728571          7.142857         2.0    9.428571
#
#              Great Stays Toronto 1  Comfy Guest House and Suite  \
# Security                  2.000000                     9.000000
# Location                  4.000000                     8.000000
# Staff                     6.000000                     8.500000
# Atmosphere                2.000000                     6.000000
# Cleanliness               2.000000                     8.000000
# Value                     2.000000                     8.500000
# Facilities                2.000000                     7.500000
# Average                   2.857143                     7.928571
#
#              Toronto Furnished Living  Pembroke Inn  \
# Security                     2.000000     10.000000
# Location                     2.000000     10.000000
# Staff                       10.000000     10.000000
# Atmosphere                   2.000000     10.000000
# Cleanliness                  2.000000     10.000000
# Value                        2.000000      8.000000
# Facilities                   2.000000     10.000000
# Average                      3.142857      9.714286
#
#              St. Lawrence Residences & Suites
# Security                             6.000000
# Location                             2.000000
# Staff                                2.000000
# Atmosphere                           2.000000
# Cleanliness                          2.000000
# Value                                2.000000
# Facilities                           2.000000
# Average                              2.571429

# %%
df_test = df_test.T.reset_index()
df_test = df_test.set_axis(['Name', 'Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value', 'Facilities', 'Average'], axis=1, copy=True)
df_test
# Out:
#                                 Name  Security  Location  Staff  Atmosphere  \
# 0             Planet Traveler Hostel       9.8       9.4    9.9         9.6
# 1                    Samesun Toronto       9.1       8.8    9.1         8.2
# 2          The Only Backpacker's Inn       9.0       8.6    9.0         8.3
# 3                    All Days Hostel       9.0       9.4    8.9         7.6
# 4       King St West and Spadina Ave       9.0      10.0    9.8         9.0
# 5                  The Clarence Park       8.6       9.0    7.9         7.7
# 6           The Parkdale Hostellerie       7.5       7.6    7.9         6.1
# 7     YYZ Nomads Women's Only Hostel       9.6       9.7    9.9         9.5
# 8                          49 Hostel       9.0       9.7    8.7         8.0
# 9                   Palmerston Hotel       6.0       9.0    7.0         7.0
# 10                        Zen Hostel       2.0       2.0    2.0         2.0
# 11                        Ode Hostel      10.0       8.0   10.0        10.0
# 12             Great Stays Toronto 1       2.0       4.0    6.0         2.0
# 13       Comfy Guest House and Suite       9.0       8.0    8.5         6.0
# 14          Toronto Furnished Living       2.0       2.0   10.0         2.0
# 15                      Pembroke Inn      10.0      10.0   10.0        10.0
# 16  St. Lawrence Residences & Suites       6.0       2.0    2.0         2.0
#
#     Cleanliness  Value  Facilities   Average
# 0           9.7    9.4         9.4  9.600000
# 1           8.4    8.2         8.1  8.557143
# 2           8.3    8.5         8.2  8.557143
# 3           8.9    8.6         8.5  8.700000
# 4           8.6    8.6         8.1  9.014286
# 5           8.6    8.0         8.0  8.257143
# 6           5.7    6.7         5.8  6.757143
# 7           9.9    9.8         9.8  9.742857
# 8           8.7    9.3         7.7  8.728571
# 9           7.0    7.0         7.0  7.142857
# 10          2.0    2.0         2.0  2.000000
# 11         10.0    8.0        10.0  9.428571
# 12          2.0    2.0         2.0  2.857143
# 13          8.0    8.5         7.5  7.928571
# 14          2.0    2.0         2.0  3.142857
# 15         10.0    8.0        10.0  9.714286
# 16          2.0    2.0         2.0  2.571429

# %%
avg_graph = df_test.iloc[:, [0,8]].head(10)
avg_graph = avg_graph.sort_values('Average', ascending=False)
avg_graph
# Out:
#                              Name   Average
# 7  YYZ Nomads Women's Only Hostel  9.742857
# 0          Planet Traveler Hostel  9.600000
# 4    King St West and Spadina Ave  9.014286
# 8                       49 Hostel  8.728571
# 3                 All Days Hostel  8.700000
# 2       The Only Backpacker's Inn  8.557143
# 1                 Samesun Toronto  8.557143
# 5               The Clarence Park  8.257143
# 9                Palmerston Hotel  7.142857
# 6        The Parkdale Hostellerie  6.757143

# %%
top_ten = avg_graph.sort_values(by= 'Average', ascending=False)[:10]

fig_height = 2 + 0.5 * len(avg_graph)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_ten)))
ax.set_yticklabels(top_ten.Name, fontsize=12)

sns.barplot(y=top_ten.Name, x=top_ten.Average, width=0.4,palette='cool')

plt.title('Top Hostels', fontsize=16, fontweight='bold')

plt.xlabel('Average Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph1.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/1497312570.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_ten.Name, x=top_ten.Average, width=0.4,palette='viridis')

# %%
highest_security = df_test.iloc[:, [0,1]].head(10)
highest_security = highest_security.sort_values('Security', ascending=False)
print(highest_security)
# Out:
#                              Name  Security
# 0          Planet Traveler Hostel       9.8
# 7  YYZ Nomads Women's Only Hostel       9.6
# 1                 Samesun Toronto       9.1
# 2       The Only Backpacker's Inn       9.0
# 3                 All Days Hostel       9.0
# 4    King St West and Spadina Ave       9.0
# 8                       49 Hostel       9.0
# 5               The Clarence Park       8.6
# 6        The Parkdale Hostellerie       7.5
# 9                Palmerston Hotel       6.0

# %%
top_security = highest_security.sort_values(by= 'Security', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_security)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_security)))
ax.set_yticklabels(top_security.Name, fontsize=12)


sns.barplot(y=top_security.Name, x=top_security.Security, width=0.4, palette='cool')

plt.title('Best Security', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14,fontweight='bold' )
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph2.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/1095602887.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_security.Name, x=top_security.Security, width=0.4, palette='viridis')

# %%
highest_location = df_test.iloc[:, [0,2]].head(10)
highest_location = highest_location.sort_values('Location', ascending=False)
print(highest_location)
# Out:
#                              Name  Location
# 4    King St West and Spadina Ave      10.0
# 7  YYZ Nomads Women's Only Hostel       9.7
# 8                       49 Hostel       9.7
# 0          Planet Traveler Hostel       9.4
# 3                 All Days Hostel       9.4
# 5               The Clarence Park       9.0
# 9                Palmerston Hotel       9.0
# 1                 Samesun Toronto       8.8
# 2       The Only Backpacker's Inn       8.6
# 6        The Parkdale Hostellerie       7.6

# %%
top_location = highest_location.sort_values(by= 'Location', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_location)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_location)))
ax.set_yticklabels(top_location.Name, fontsize=12)

sns.barplot(y=top_location.Name, x=top_location.Location, width=0.4, palette='cool')

plt.title('Best Location', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph3.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/1657163095.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_location.Name, x=top_location.Location, width=0.4, palette='viridis')

# %%
highest_staff = df_test.iloc[:, [0,3]].head(10)
highest_staff = highest_staff.sort_values('Staff', ascending=False)
print(highest_staff)
# Out:
#                              Name  Staff
# 0          Planet Traveler Hostel    9.9
# 7  YYZ Nomads Women's Only Hostel    9.9
# 4    King St West and Spadina Ave    9.8
# 1                 Samesun Toronto    9.1
# 2       The Only Backpacker's Inn    9.0
# 3                 All Days Hostel    8.9
# 8                       49 Hostel    8.7
# 5               The Clarence Park    7.9
# 6        The Parkdale Hostellerie    7.9
# 9                Palmerston Hotel    7.0

# %%
top_staff = highest_staff.sort_values(by= 'Staff', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_staff)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_staff)))
ax.set_yticklabels(top_staff.Name, fontsize=12)

sns.barplot(y=top_staff.Name, x=top_staff.Staff, width=0.4, palette='cool')

plt.title('Best Staff', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph4.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/3461761864.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_staff.Name, x=top_staff.Staff, width=0.4, palette='viridis')

# %%
highest_atmosphere = df_test.iloc[:, [0,4]].head(10)
highest_atmosphere = highest_atmosphere.sort_values('Atmosphere', ascending=False)
print(highest_atmosphere)
# Out:
#                              Name  Atmosphere
# 0          Planet Traveler Hostel         9.6
# 7  YYZ Nomads Women's Only Hostel         9.5
# 4    King St West and Spadina Ave         9.0
# 2       The Only Backpacker's Inn         8.3
# 1                 Samesun Toronto         8.2
# 8                       49 Hostel         8.0
# 5               The Clarence Park         7.7
# 3                 All Days Hostel         7.6
# 9                Palmerston Hotel         7.0
# 6        The Parkdale Hostellerie         6.1

# %%
top_atmosphere = highest_atmosphere.sort_values(by= 'Atmosphere', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_atmosphere)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_atmosphere)))
ax.set_yticklabels(top_atmosphere.Name, fontsize=12)

sns.barplot(y=top_atmosphere.Name, x=top_atmosphere.Atmosphere, width=0.4, palette='cool')

plt.title('Best Atmosphere', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph5.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/3805934551.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_atmosphere.Name, x=top_atmosphere.Atmosphere, width=0.4, palette='viridis')

# %%
highest_clean = df_test.iloc[:, [0,5]].head(10)
highest_clean = highest_clean.sort_values('Cleanliness', ascending=False)
print(highest_clean)
# Out:
#                              Name  Cleanliness
# 7  YYZ Nomads Women's Only Hostel          9.9
# 0          Planet Traveler Hostel          9.7
# 3                 All Days Hostel          8.9
# 8                       49 Hostel          8.7
# 4    King St West and Spadina Ave          8.6
# 5               The Clarence Park          8.6
# 1                 Samesun Toronto          8.4
# 2       The Only Backpacker's Inn          8.3
# 9                Palmerston Hotel          7.0
# 6        The Parkdale Hostellerie          5.7

# %%
top_clean = highest_clean.sort_values(by= 'Cleanliness', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_clean)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_clean)))
ax.set_yticklabels(top_clean.Name, fontsize=12)

sns.barplot(y=top_clean.Name, x=top_clean.Cleanliness, width=0.4, palette='cool')

plt.title('Best Cleanliness', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=16, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=16, fontweight='bold')

plt.savefig('static/graph6.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/339044005.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_clean.Name, x=top_clean.Cleanliness, width=0.4, palette='viridis')

# %%
highest_value = df_test.iloc[:, [0,6]].head(10)
highest_value = highest_value.sort_values('Value', ascending=False)
print(highest_value)
# Out:
#                              Name  Value
# 7  YYZ Nomads Women's Only Hostel    9.8
# 0          Planet Traveler Hostel    9.4
# 8                       49 Hostel    9.3
# 3                 All Days Hostel    8.6
# 4    King St West and Spadina Ave    8.6
# 2       The Only Backpacker's Inn    8.5
# 1                 Samesun Toronto    8.2
# 5               The Clarence Park    8.0
# 9                Palmerston Hotel    7.0
# 6        The Parkdale Hostellerie    6.7

# %%
top_value = highest_value.sort_values(by= 'Value', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_value)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_value)))
ax.set_yticklabels(top_value.Name, fontsize=12)

sns.barplot(y=top_value.Name, x=top_value.Value, width=0.4, palette='cool')

plt.title('Best Value', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph7.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/1464707231.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_value.Name, x=top_value.Value, width=0.4, palette='viridis')

# %%
highest_facility = df_test.iloc[:, [0,7]].head(10)
highest_facility = highest_facility.sort_values('Facilities', ascending=False)
print(highest_facility)
# Out:
#                              Name  Facilities
# 7  YYZ Nomads Women's Only Hostel         9.8
# 0          Planet Traveler Hostel         9.4
# 3                 All Days Hostel         8.5
# 2       The Only Backpacker's Inn         8.2
# 1                 Samesun Toronto         8.1
# 4    King St West and Spadina Ave         8.1
# 5               The Clarence Park         8.0
# 8                       49 Hostel         7.7
# 9                Palmerston Hotel         7.0
# 6        The Parkdale Hostellerie         5.8

# %%
top_facility = highest_facility.sort_values(by= 'Facilities', ascending=False)[:20]

fig_height = 2 + 0.5 * len(top_facility)
fig, ax = plt.subplots(figsize=(10,fig_height))

ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
ax.set_xticklabels(ax.get_xticks(), fontsize=12)

ax.set_yticks(range(len(top_facility)))
ax.set_yticklabels(top_facility.Name, fontsize=12)

sns.barplot(y=top_facility.Name, x=top_facility.Facilities, width=0.4, palette='cool')

plt.title('Best Facilities', fontsize=16, fontweight='bold')

plt.xlabel('Rating', fontsize=14, fontweight='bold')
plt.ylabel('Hostel Name', fontsize=14, fontweight='bold')

plt.savefig('static/graph8.png', bbox_inches='tight')

plt.show()

plt.close()
# Out:
# /var/folders/gf/cr37zbpx4y538lybk11nb5nr0000gn/T/ipykernel_70770/2032170511.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_facility.Name, x=top_facility.Facilities, width=0.4, palette='cool')
